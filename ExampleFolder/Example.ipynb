# %%
from stsci.tools import capable
capable.OF_GRAPHICS = False

from pyraf import iraf
from pyraf.iraf import gemini, gemtools, gmos
import fileSelect as fs
import copy

# %% [markdown]
# First specified the directory where all the data was downloaded and extracted. Then defined the sqlite3 database. This contains the information of all the files and

# %%
datadirall = '../rawExample/'
databasename = datadirall+'obsLog.sqlite3'
dbFile= datadirall+'obsLog.sqlite3'

# %% [markdown]
#  From the work_directory:
#  Create the query dictionary of essential parameter=value pairs.

# %%
qd = {'Full':{'use_me':1,
       'Instrument':'GMOS-S','CcdBin':'2 4','RoI':'Full',
       'Disperser':'B600+_%','CentWave':485.0,'AperMask':'1.0arcsec',
       'Object':'AM2306-72%',
       'DateObs':'2007-06-05:2007-07-07'}
      }
# Make copy for the CenterSpec RoI:
qd['CenSp'] = copy.deepcopy(qd['Full'])
qd['CenSp'].update({'RoI':'CentSp','Object':'LTT9239'})

# %% [markdown]
#  In the tutorial there are two regions but here only one and it is full. Just changed the regions list to only Full. It should workl

# %%
gemtools.gemextn.unlearn()    # Disarm a bug in gbias
gmos.gbias.unlearn()
biasFlags = {
    'logfile':'biasLog.txt','rawpath':'../rawExample/','fl_vardq':'yes','verbose':'no'
}
regions = ['Full','CenSp']
for r in regions:
    # The following SQL generates the list of full-frame files to process.
    SQL = fs.createQuery('bias', qd[r])
    biasFiles = fs.fileListQuery(dbFile, SQL, qd[r])

    # The str.join() funciton is needed to transform a python list into a
    # comma-separated string of file names that IRAF can understand.
    if len(biasFiles) > 1:
        gmos.gbias(','.join(str(x) for x in biasFiles), 'MCbias'+r,
                   **biasFlags)
# Out:
# ERROR - GBIAS: Output file MCbiasFull.fits already exists.
# ERROR - GBIAS: File ../rawExample/GS20070622S0151_BIAS not found.

# %% [markdown]
# # Flat Field

# %%
# Set the task parameters.
qd['Full'].update({'DateObs':'*'})

# %%
gmos.gireduce.unlearn()
gmos.gsflat.unlearn()
# The response fitting should be done interactively.
flatFlags = {
    'fl_over':'yes','fl_trim':'yes','fl_bias':'yes','fl_dark':'no',
    'fl_fixpix':'no','fl_oversize':'no','fl_vardq':'yes','fl_fulldq':'yes',
    'rawpath':'../raw','fl_inter':'no','fl_detec':'yes',
    'function':'spline3','order':'13,11,28',
    'logfile':'gsflatLog.txt','verbose':'no'
    }
for r in regions:
    qr = qd[r]
    flatFiles = fs.fileListQuery(dbFile, fs.createQuery('gcalFlat', qr), qr)
    if len(flatFiles) > 0:
        gmos.gsflat (','.join(str(x) for x in flatFiles), 'MCflat'+r,
                bias='MCbias'+r, **flatFlags)
# Out:
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# --------------------------------------------------------------------------------
# GEMCOMBINE -- Wed Oct 31 14:23:44 CDT 2018
#
# GEMCOMBINE: input = @tmpscilist22197_623
# GEMCOMBINE: output = tmpcombflat22197_626
# GEMCOMBINE: title =
# GEMCOMBINE: bpmfile =
# GEMCOMBINE: sci_ext = SCI
# GEMCOMBINE: var_ext = VAR
# GEMCOMBINE: dq_ext = DQ
#
#
# Oct 31 14:23: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:23
#   masktype = goodval, maskval = 0
#                 Images     Mean  Scale Maskfile
#   gsS20180708S0084.fits[SCI,1]  36452.  1.000 tmpdq22197_1375_1.pl
#   gsS20180709S0144.fits[SCI,1]  36611.  0.996 tmpdq22197_1375_2.pl
#   gsS20180709S0153.fits[SCI,1]  35710.  1.021 tmpdq22197_1375_3.pl
#
#   Output image = tmpcombout22197_1391, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1392.pl
#   Sigma image = tmpcombsig22197_1393
#
# Oct 31 14:23: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:23
#   masktype = goodval, maskval = 0
#                 Images     Mean  Scale Maskfile
#   gsS20180708S0084.fits[SCI,3]  20392.  1.000 tmpdq22197_1375_1.pl
#   gsS20180709S0144.fits[SCI,3]  20395.  1.000 tmpdq22197_1375_2.pl
#   gsS20180709S0153.fits[SCI,3]  20288.  1.005 tmpdq22197_1375_3.pl
#   gsS20180711S0120.fits[SCI,3]  20268.  1.006 tmpdq22197_1375_4.pl
#   gsS20180711S0197.fits[SCI,3]  20494.  0.995 tmpdq22197_1375_5.pl
#   gsS20180717S0040.fits[SCI,3]  19931.  1.023 tmpdq22197_1375_6.pl
#   gsS20180717S0049.fits[SCI,3]  20283.  1.005 tmpdq22197_1375_7.pl
#   gsS20180912S0035.fits[SCI,3]  21324.  0.956 tmpdq22197_1375_8.pl
#   gsS20180918S0023.fits[SCI,3]  21392.  0.953 tmpdq22197_1375_9.pl
#   gsS20180918S0032.fits[SCI,3]  21058.  0.968 tmpdq22197_1375_10.pl
#   gsS20180918S0041.fits[SCI,3]  21722.  0.939 tmpdq22197_1375_11.pl
#   gsS20180925S0073.fits[SCI,3]  20982.  0.972 tmpdq22197_1375_12.pl
#   gsS20180926S0021.fits[SCI,3]  21235.  0.960 tmpdq22197_1375_13.pl
#   gsS20180926S0030.fits[SCI,3]  21032.  0.970 tmpdq22197_1375_14.pl
#   gsS20181004S0024.fits[SCI,3]  21192.  0.962 tmpdq22197_1375_15.pl
#
#   Output image = tmpcombout22197_1395, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1396.pl
#   Sigma image = tmpcombsig22197_1397
#
# Oct 31 14:23: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:23
#   masktype = goodval, maskval = 0
#                 Images     Mean  Scale Maskfile
#   gsS20180708S0084.fits[SCI,4]  19556.  1.000 tmpdq22197_1375_1.pl
#   gsS20180709S0144.fits[SCI,4]  19540.  1.001 tmpdq22197_1375_2.pl
#   gsS20180709S0153.fits[SCI,4]  19464.  1.005 tmpdq22197_1375_3.pl
#   gsS20180711S0120.fits[SCI,4]  19444.  1.006 tmpdq22197_1375_4.pl
#   gsS20180711S0197.fits[SCI,4]  19636.  0.996 tmpdq22197_1375_5.pl
#   gsS20180717S0040.fits[SCI,4]  19129.  1.022 tmpdq22197_1375_6.pl
#   gsS20180717S0049.fits[SCI,4]  19461.  1.005 tmpdq22197_1375_7.pl
#   gsS20180912S0035.fits[SCI,4]  20453.  0.956 tmpdq22197_1375_8.pl
#   gsS20180918S0023.fits[SCI,4]  20522.  0.953 tmpdq22197_1375_9.pl
#   gsS20180918S0032.fits[SCI,4]  20203.  0.968 tmpdq22197_1375_10.pl
#   gsS20180918S0041.fits[SCI,4]  20849.  0.938 tmpdq22197_1375_11.pl
#   gsS20180925S0073.fits[SCI,4]  20111.  0.972 tmpdq22197_1375_12.pl
#   gsS20180926S0021.fits[SCI,4]  20359.  0.961 tmpdq22197_1375_13.pl
#   gsS20180926S0030.fits[SCI,4]  20174.  0.969 tmpdq22197_1375_14.pl
#   gsS20181004S0024.fits[SCI,4]  20324.  0.962 tmpdq22197_1375_15.pl
#
#   Output image = tmpcombout22197_1399, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1400.pl
#   Sigma image = tmpcombsig22197_1401
#
# Oct 31 14:23: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:23
#   masktype = goodval, maskval = 0
#                 Images     Mean  Scale Maskfile
#   gsS20180708S0084.fits[SCI,5]  17619.  1.000 tmpdq22197_1375_1.pl
#   gsS20180709S0144.fits[SCI,5]  17596.  1.001 tmpdq22197_1375_2.pl
#   gsS20180709S0153.fits[SCI,5]  17504.  1.007 tmpdq22197_1375_3.pl
#   gsS20180711S0120.fits[SCI,5]  17514.  1.006 tmpdq22197_1375_4.pl
#   gsS20180711S0197.fits[SCI,5]  17700.  0.995 tmpdq22197_1375_5.pl
#   gsS20180717S0040.fits[SCI,5]  17202.  1.024 tmpdq22197_1375_6.pl
#   gsS20180717S0049.fits[SCI,5]  17546.  1.004 tmpdq22197_1375_7.pl
#   gsS20180912S0035.fits[SCI,5]  20100.  0.877 tmpdq22197_1375_8.pl
#   gsS20180918S0023.fits[SCI,5]  20318.  0.867 tmpdq22197_1375_9.pl
#   gsS20180918S0032.fits[SCI,5]  19963.  0.883 tmpdq22197_1375_10.pl
#   gsS20180918S0041.fits[SCI,5]  20604.  0.855 tmpdq22197_1375_11.pl
#   gsS20180925S0073.fits[SCI,5]  19873.  0.887 tmpdq22197_1375_12.pl
#   gsS20180926S0021.fits[SCI,5]  20149.  0.874 tmpdq22197_1375_13.pl
#   gsS20180926S0030.fits[SCI,5]  19925.  0.884 tmpdq22197_1375_14.pl
#   gsS20181004S0024.fits[SCI,5]  20131.  0.875 tmpdq22197_1375_15.pl
#
#   Output image = tmpcombout22197_1403, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1404.pl
#   Sigma image = tmpcombsig22197_1405
#
# Oct 31 14:23: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:23
#                 Images     Mean  Scale
#   gsS20180708S0084.fits[SCI,6]  14357.  1.000
#   gsS20180709S0144.fits[SCI,6]  14322.  1.002
#   gsS20180709S0153.fits[SCI,6]  14253.  1.007
#   gsS20180711S0120.fits[SCI,6]  14277.  1.006
#   gsS20180711S0197.fits[SCI,6]  14417.  0.996
#   gsS20180717S0040.fits[SCI,6]  14074.  1.020
#   gsS20180717S0049.fits[SCI,6]  14346.  1.001
#   gsS20180912S0035.fits[SCI,6]  14975.  0.959
#   gsS20180918S0023.fits[SCI,6]  15058.  0.953
#   gsS20180918S0032.fits[SCI,6]  14846.  0.967
#   gsS20180918S0041.fits[SCI,6]  15326.  0.937
#   gsS20180925S0073.fits[SCI,6]  14699.  0.977
#   gsS20180926S0021.fits[SCI,6]  14917.  0.962
#   gsS20180926S0030.fits[SCI,6]  14780.  0.971
#   gsS20181004S0024.fits[SCI,6]  14895.  0.964
#
#   Output image = tmpcombout22197_1407, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1408.pl
#   Sigma image = tmpcombsig22197_1409
#
# Oct 31 14:23: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:23
#                 Images     Mean  Scale
#   gsS20180708S0084.fits[SCI,7]  10660.  1.000
#   gsS20180709S0144.fits[SCI,7]  10639.  1.002
#   gsS20180709S0153.fits[SCI,7]  10609.  1.005
#   gsS20180711S0120.fits[SCI,7]  10598.  1.006
#   gsS20180711S0197.fits[SCI,7]  10691.  0.997
#   gsS20180717S0040.fits[SCI,7]  10432.  1.022
#   gsS20180717S0049.fits[SCI,7]  10619.  1.004
#   gsS20180912S0035.fits[SCI,7]  11123.  0.958
#   gsS20180918S0023.fits[SCI,7]  11145.  0.956
#   gsS20180918S0032.fits[SCI,7]  10976.  0.971
#   gsS20180918S0041.fits[SCI,7]  11342.  0.940
#   gsS20180925S0073.fits[SCI,7]  10918.  0.976
#   gsS20180926S0021.fits[SCI,7]  11070.  0.963
#   gsS20180926S0030.fits[SCI,7]  10976.  0.971
#   gsS20181004S0024.fits[SCI,7]  11051.  0.965
#
#   Output image = tmpcombout22197_1411, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1412.pl
#   Sigma image = tmpcombsig22197_1413
#
# Oct 31 14:23: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:23
#   masktype = goodval, maskval = 0
#                 Images     Mean  Scale Maskfile
#   gsS20180708S0084.fits[SCI,8]  12225.  1.000 tmpdq22197_1375_1.pl
#   gsS20180709S0144.fits[SCI,8]  12188.  1.003 tmpdq22197_1375_2.pl
#   Sigma image = tmpcombsig22197_1421
#
# Oct 31 14:24: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:24
#                 Images     Mean  Scale
#   gsS20180708S0084.fits[SCI,10]  7629.7  1.000
#   gsS20180709S0144.fits[SCI,10]  7595.2  1.005
#   gsS20180709S0153.fits[SCI,10]  7544.4  1.011
#   gsS20180711S0120.fits[SCI,10]  7599.1  1.004
#   gsS20180711S0197.fits[SCI,10]  7637.1  0.999
#   gsS20180717S0040.fits[SCI,10]  7478.4  1.020
#   gsS20180717S0049.fits[SCI,10]  7620.3  1.001
#   gsS20180912S0035.fits[SCI,10]  8023.1  0.951
#   gsS20180918S0023.fits[SCI,10]  8029.8  0.950
#   gsS20180918S0032.fits[SCI,10]   7918.  0.964
#   gsS20180918S0041.fits[SCI,10]  8179.7  0.933
#   gsS20180925S0073.fits[SCI,10]  7806.8  0.977
#   gsS20180926S0021.fits[SCI,10]  7933.9  0.962
#   gsS20180926S0030.fits[SCI,10]  7861.7  0.970
#   gsS20181004S0024.fits[SCI,10]   7908.  0.965
#
#   Output image = tmpcombout22197_1423, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1424.pl
#   Sigma image = tmpcombsig22197_1425
#
# Oct 31 14:24: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:24
#   masktype = goodval, maskval = 0
#                 Images     Mean  Scale Maskfile
#   gsS20180708S0084.fits[SCI,11]   4298.  1.000 tmpdq22197_1375_1.pl
#   gsS20180709S0144.fits[SCI,11]  4275.9  1.005 tmpdq22197_1375_2.pl
#   gsS20180709S0153.fits[SCI,11]  4244.5  1.013 tmpdq22197_1375_3.pl
#   gsS20180711S0120.fits[SCI,11]  4276.7  1.005 tmpdq22197_1375_4.pl
#   gsS20180711S0197.fits[SCI,11]   4306.  0.998 tmpdq22197_1375_5.pl
#   gsS20180717S0040.fits[SCI,11]  4212.4  1.020 tmpdq22197_1375_6.pl
#   gsS20180717S0049.fits[SCI,11]  4297.9  1.000 tmpdq22197_1375_7.pl
#   gsS20180912S0035.fits[SCI,11]  4518.3  0.951 tmpdq22197_1375_8.pl
#   gsS20180918S0023.fits[SCI,11]  4528.3  0.949 tmpdq22197_1375_9.pl
#   gsS20180918S0032.fits[SCI,11]  4470.1  0.961 tmpdq22197_1375_10.pl
#   gsS20180918S0041.fits[SCI,11]  4616.1  0.931 tmpdq22197_1375_11.pl
#   gsS20180925S0073.fits[SCI,11]  4389.5  0.979 tmpdq22197_1375_12.pl
#   gsS20180926S0021.fits[SCI,11]  4478.6  0.960 tmpdq22197_1375_13.pl
#   gsS20180926S0030.fits[SCI,11]  4433.7  0.969 tmpdq22197_1375_14.pl
#   gsS20181004S0024.fits[SCI,11]  4464.1  0.963 tmpdq22197_1375_15.pl
#
#   Output image = tmpcombout22197_1427, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1428.pl
#   Sigma image = tmpcombsig22197_1429
#
# Oct 31 14:24: IMCOMBINE
#   combine = average, scale = mean, zero = none, weight = none
#   reject = avsigclip, mclip = yes, nkeep = 0
#   lsigma = 3., hsigma = 3.
#   blank = 0.
#   statsec = Oct 31 14:24
#                 Images     Mean  Scale
#   gsS20180708S0084.fits[SCI,12]  1197.9  1.000
#   gsS20180709S0144.fits[SCI,12]  1185.5  1.010
#   gsS20180709S0153.fits[SCI,12]   1198.  1.000
#   gsS20180711S0120.fits[SCI,12]  1186.2  1.010
#   gsS20180711S0197.fits[SCI,12]  1197.7  1.000
#   gsS20180717S0040.fits[SCI,12]  1180.3  1.015
#   gsS20180717S0049.fits[SCI,12]  1201.8  0.997
#   gsS20180912S0035.fits[SCI,12]  1237.8  0.968
#   gsS20180918S0023.fits[SCI,12]  1248.9  0.959
#   gsS20180918S0032.fits[SCI,12]  1231.2  0.973
#   gsS20180918S0041.fits[SCI,12]  1270.7  0.943
#   gsS20180925S0073.fits[SCI,12]  1217.7  0.984
#   gsS20180926S0021.fits[SCI,12]  1241.3  0.965
#   gsS20180926S0030.fits[SCI,12]  1228.8  0.975
#   gsS20181004S0024.fits[SCI,12]   1238.  0.968
#
#   Output image = tmpcombout22197_1431, ncombine = 15
#   Number rejected mask = tmpcombdq22197_1432.pl
#   Sigma image = tmpcombsig22197_1433
# GEMCOMBINE: Attaching the MDF
#
# GEMCOMBINE -- Finished: Wed Oct 31 14:24:07 CDT 2018
#
# GEMCOMBINE -- Exit status: GOOD
# --------------------------------------------------------------------------------
# WARNING- GSFLAT: order of fitting function must be greater than zero
# WARNING- GSFLAT: setting order of fitting function to 13 for all amps.
#
# GSFLAT done Wed Oct 31 14:24:13 CDT 2018

# %% [markdown]
# # Basic Reduction

# %%
# Set task parameters.
gmos.gsreduce.unlearn()
sciFlags = {
    'fl_over':'yes','fl_trim':'yes','fl_bias':'yes','fl_gscrrej':'no',
    'fl_dark':'no','fl_flat':'yes','fl_gmosaic':'yes','fl_fixpix':'no',
    'fl_gsappwave':'yes','fl_oversize':'no',
    'fl_vardq':'yes','fl_fulldq':'yes','rawpath':'../raw',
    'fl_inter':'no','logfile':'gsreduceLog.txt','verbose':'no'
}
arcFlags = copy.deepcopy(sciFlags)
arcFlags.update({'fl_flat':'no','fl_vardq':'no','fl_fulldq':'no'})
stdFlags = copy.deepcopy(sciFlags)
stdFlags.update({'fl_fixpix':'yes','fl_vardq':'no','fl_fulldq':'no'})

# Arc exposures
for r in regions:
    qr = qd[r]
    arcFiles = fs.fileListQuery(dbFile, fs.createQuery('arc', qr), qr)
    if len(arcFiles) > 0:
        gmos.gsreduce (','.join(str(x) for x in arcFiles), bias='MCbias'+r,
                  **arcFlags)

# Science exposures
r = 'Full'
sciFiles = fs.fileListQuery(dbFile, fs.createQuery('sciSpec', qd[r]), qd[r])
if len(sciFiles) > 0:
    gmos.gsreduce (','.join(str(x) for x in sciFiles), bias='MCbias'+r,
              flatim='MCflat'+r, **sciFlags)
# Out:
# GPREPARE: Using MDF defined in the header 0.5arcsec
# GPREPARE: Using MDF defined in the header 0.5arcsec
# GPREPARE: Using MDF defined in the header 0.5arcsec
# GPREPARE: Using MDF defined in the header 0.5arcsec
# GPREPARE: Using MDF defined in the header 0.5arcsec
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged
# GPREPARE: Using MDF defined in the header 0.5arcsec
# WARNING - GIREDUCE: Bad Pixel Mask filename is an empty string
#                     Only saturated pixels will be flagged

# %% [markdown]
# # Wavelength Calibration (Check this later)
#
# Image rectification and wavelength linearization depend upon the wavelength calibration, using the arc lamp exposures taken immediately before each sequence of science and standard star exposures (see Wavelength Calibration). In this case, the default medium-resolution line list will work well. The fit to the dispersion relation should be performed interactively, but for expediency we will use a previously determined functional fit.
#
#
# I had tpo manually put the name of the two arc Files. I am not sure how may to use.

# %%
# Set task parameters
gmos.gswavelength.unlearn()
waveFlags = {
    'coordlist':'gmos$data/CuAr_GMOS.dat','fwidth':6,'nsum':50,
    'function':'chebyshev','order':5,
    'fl_inter':'no','logfile':'gswaveLog.txt','verbose':'no'
    }
# Must select specific wavecals to match science exposures.
#prefix = 'gsS20180922S0'
for arc in ['gsS20180928S0014', 'gsS20181004S0209']:
     gmos.gswavelength (arc, **waveFlags)

# %% [markdown]
# # Advanced Processing
#
# The targets in this program were observed in 3 slit orientations, and a few exposures were obtained at each position. This provides an opportunity to combine the sequential exposures at each position to remove cosmic rays, rather than rejecting CRs on single frames using the gsreduce.fl_gscrrej+ flag or running the gemcrspec task. The combined exposures for each target are then wavelength calibrated, and sky subtracted. First set the processing parameters.

# %%
# Set task parameters.
gemtools.gemcombine.unlearn()
sciCombFlags = {
    'combine':'average','reject':'ccdclip',
    'fl_vardq':'yes','fl_dqprop':'yes',
    'logfile':'gemcombineLog.txt.txt','verbose':'no'
}
stdCombFlags = copy.deepcopy(sciCombFlags)
stdCombFlags.update({'fl_vardq':'no','fl_dqprop':'no'})
gmos.gstransform.unlearn()
transFlags = {
    'fl_vardq':'yes','interptype':'linear','fl_flux':'yes',
    'logfile':'gstransLog.txt'
}
# The sky regions should be selected with care, using e.g. prows/pcols:
#   pcols ("tAM2306b.fits[SCI]", 1100, 2040, wy1=40, wy2=320)
gmos.gsskysub.unlearn()
skyFlags = {
    'fl_oversize':'no','fl_vardq':'yes','logfile':'gsskysubLog.txt'
}

# %% [markdown]
# # Science Targets
