# %%
import sys

sys.path.append('../')

from spectra import reducedgemini
# Out:
# uparm parameter list `/home/mmarcano/anaconda3/envs/astroconda/iraf/noao/imred/ccdred/ccdtest/ccdtest.par' inconsistent with default parameters for IrafPkg `ccdtest'
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#Inputs

qd = {'Full':{'use_me':1,
       'Instrument':'GMOS-S','CcdBin':'2 4','RoI':'Full',
       'Disperser':'B600+_%','CentWave':485.0,'AperMask':'1.0arcsec',
       'Object':'AM2306-72%',
       'DateObs':'2007-06-05:2007-07-07'}
      }

datadirall = '../rawExample/'

arcname = 'gsS20070623S0071'

reducedgemini(qd,arcname,datadirall='../rawExample/',ds9=False,skyreg='100:500')
# Out:
# ERROR - GBIAS: Output file MCbiasFull.fits already exists.
# ERROR - GSFLAT: Output file MCflatFull already exists.
# ERROR - GSFLAT: 1 fatal errors found.
#
# ERROR - GSFLAT: Program execution failed with 1 errors.
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0062.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0071.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0081.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0091.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0122.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0123.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0124.fits does not exist
# ERROR - GSREDUCE: Exiting with 7 errors
#
# ERROR - GSREDUCE: Program execution failed with 7 errors
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0072.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0073.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0074.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0075.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0082.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0083.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0084.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0085.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0092.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0097.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0098.fits does not exist
# ERROR - GSREDUCE: Input image : ../raw/S20070623S0099.fits does not exist
# ERROR - GSREDUCE: Exiting with 12 errors
#
# ERROR - GSREDUCE: Program execution failed with 12 errors
# ERROR - GSWAVELENGTH: gsgsS20070623S0071 does not exist or is not a MEF
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c3961143ad61> in <module>()
#      12 arcname = 'gsS20070623S0071'
#      13
# ---> 14 reducedgemini(qd,arcname,datadirall='../rawExample/',ds9=False,skyreg='100:500')
#      15
#      16
#
# /home/mmarcano/Documents/GeminiReduceTTU/spectra.pyc in reducedgemini(qd, arcname, datadirall, ds9, skyreg)
#     210         sciFiles = fs.fileListQuery(dbFile, fs.createQuery('sciSpec', qs), qs)
#     211         gemtools.gemcombine (','.join(prefix+str(x) for x in sciFiles),
# --> 212                              sciOut, **sciCombFlags)
#     213         gmos.gstransform(sciOut, wavtraname=p['arc'], **transFlags)
#     214         gmos.gsskysub('t'+sciOut, long_sample=p['sky'], **skyFlags)
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in __call__(self, *args, **kw)
#     765
#     766     def __call__(self,*args,**kw):
# --> 767         return self.run(*args, **kw)
#     768
#     769     def __repr__(self):
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in run(self, *args, **kw)
#     357             if executionMonitor:
#     358                 executionMonitor(self)
# --> 359             self._run(redirKW, specialKW)
#     360             self._updateParList(save)
#     361             if Verbose>1:
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in _run(self, redirKW, specialKW)
#    1453     def _run(self, redirKW, specialKW):
#    1454         """Execute task after parameters, I/O redirection are prepared."""
# -> 1455         self._runCode()
#    1456
#    1457     def _runCode(self, parList=None, kw={}):
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in _runCode(self, parList, kw)
#    1468         # name for the parameter.)
#    1469         #XXX
# -> 1470         self._clFunction(*parList, **kw)
#    1471
#    1472     def _noParFile(self):
#
# <CL script gemtools.gemcombine> in gemcombine(input, output, title, combine, reject, offsets, masktype, maskvalue, scale, zero, weight, statsec, expname, lthreshold, hthreshold, nlow, nhigh, nkeep, mclip, lsigma, hsigma, key_ron, key_gain, ron, gain, snoise, sigscale, pclip, grow, bpmfile, nrejfile, sci_ext, var_ext, dq_ext, fl_vardq, logfile, fl_dqprop, verbose, status, flist, scanfile, mode, DOLLARnargs, taskObj)
#     632                                         iraf.imgets(Vars.combsig, 'GAINORIG', Stderr='dev$null')
#     633                                         if (iraf.imgets.value == '0'):
# --> 634                                                 iraf.gemhedit(Vars.combsig, 'GAINORIG',(iraf.real(Vars.l_sgain)**2),'Input gain',delete=no)
#     635                                         iraf.imgets(Vars.combsig, 'RONORIG', Stderr='dev$null')
#     636                                         if (iraf.imgets.value == '0'):
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in __call__(self, *args, **kw)
#     765
#     766     def __call__(self,*args,**kw):
# --> 767         return self.run(*args, **kw)
#     768
#     769     def __repr__(self):
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in run(self, *args, **kw)
#     357             if executionMonitor:
#     358                 executionMonitor(self)
# --> 359             self._run(redirKW, specialKW)
#     360             self._updateParList(save)
#     361             if Verbose>1:
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in _run(self, redirKW, specialKW)
#    1453     def _run(self, redirKW, specialKW):
#    1454         """Execute task after parameters, I/O redirection are prepared."""
# -> 1455         self._runCode()
#    1456
#    1457     def _runCode(self, parList=None, kw={}):
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in _runCode(self, parList, kw)
#    1468         # name for the parameter.)
#    1469         #XXX
# -> 1470         self._clFunction(*parList, **kw)
#    1471
#    1472     def _noParFile(self):
#
# <CL script gemtools.gemhedit> in gemhedit(image, field, value, comment, delete, upfile, status, mode, DOLLARnargs, taskObj)
#     116                                         iraf.imutil.nhedit(Vars.l_image, Vars.l_field, 'CHANGEME',comment = Vars.l_comment,comfile = Vars.l_upfile,after = '',before = '',update = Vars.l_update,add = Vars.l_add,addonly = Vars.l_addonly,delete = Vars.l_delete,verify=no,show = Vars.l_show)
#     117                                         Vars.l_comment = '.'
# --> 118                                 iraf.imutil.nhedit(Vars.l_image, Vars.l_field, Vars.l_value,comment = Vars.l_comment,comfile = Vars.l_upfile,after = '',before = '',update = Vars.l_update,add = Vars.l_add,addonly = Vars.l_addonly,delete = Vars.l_delete,verify=no,show = Vars.l_show)
#     119                         else:
#     120                                 iraf.clPrint('ERROR - GEMHEDIT: No NHEDIT found')
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in __call__(self, *args, **kw)
#     765
#     766     def __call__(self,*args,**kw):
# --> 767         return self.run(*args, **kw)
#     768
#     769     def __repr__(self):
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in run(self, *args, **kw)
#     340         # copy of the par list, during the life of this PyRAF session.
#     341         kw['_setMode'] = 1
# --> 342         self.setParList(*args, **kw)
#     343
#     344         if Verbose>1:
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/site-packages/pyraf/iraftask.pyc in setParList(self, *args, **kw)
#     444                 newParList = copy.deepcopy(parList)
#     445             else:
# --> 446                 newParList = copy.deepcopy(self._currentParList)
#     447
#     448         if '_setMode' in kw:
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/copy.pyc in _deepcopy_inst(x, memo)
#     286     if hasattr(x, '__getinitargs__'):
#     287         args = x.__getinitargs__()
# --> 288         args = deepcopy(args, memo)
#     289         y = x.__class__(*args)
#     290     else:
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# /home/mmarcano/anaconda3/envs/astroconda/lib/python2.7/copy.pyc in _deepcopy_tuple(x, memo)
#     239     try:
#     240         return memo[d]
# --> 241     except KeyError:
#     242         pass
#     243     for i in range(len(x)):
#
# KeyboardInterrupt:
